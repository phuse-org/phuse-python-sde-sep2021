# %% [markdown]
# # The CDISC Library API
#
# There's no other way to put it - PDF is a terrible medium for data sharing.  There is a standard, but implementations of it are wide and varied.  Issues around handling tables, paragraphs, etc have made it a very human (and thereby accident prone) approach.
#
# The CDISC Library exposes the core metadata via a RESTful Web API.  Access is available for members with fair use provisions and also for Open Source Contributors if you are eligible.  To request an account go to [CDISC Library](https://www.cdisc.org/cdisc-library) and click on `Request an account`.  Once you are setup you will be able to generate a token (a character string) that you can use to make requests against the API (this is primarily used to avoid people abusing the service)

# %%
# as before, we import our requests library
import requests

# We use the python-dotenv library to merge in the CDISC_LIBRARY_API_TOKEN
#  - this reads from a formatted file and adds the values to the environment
from dotenv import load_dotenv
# this loads in the values from the .env file
load_dotenv()
import os

# prove it worked
print(f"Loaded token {os.environ['CDISC_LIBRARY_API_TOKEN'][:5]}...")

# Supply this globally
CDISC_API_URL = "https://library.cdisc.org/api"
# Out:
# Loaded token ed516...

# %%
# the token we loaded needs to be added to the headers using the name 'api-key'

# if we don't pass the token, what happens?
unauth = requests.get(f"{CDISC_API_URL}/mdr/products")

print(f"Requesting {unauth.url} got status {unauth.status_code}")
# Out:
# Requesting https://library.cdisc.org/api/mdr/products got status 401

# %%
# we pass the `api-key` in the headers

response = requests.get(f"{CDISC_API_URL}/mdr/products", headers={'api-key': os.environ['CDISC_LIBRARY_API_TOKEN']})

print(f"Requesting {response.url} got status {response.status_code}")
# Out:
# Requesting https://library.cdisc.org/api/mdr/products got status 200

# %%
# The request we made above was to the webservice that returns the list of products

# as we know the response is JSON we can access the model as a dictionary using the `json` method
results = response.json()

# What elements are in the result set?
print("Keys", results.keys())
# Out:
# Keys dict_keys(['_links'])

# %%
# Inspection of this object helps us find what we are looking for

links = results.get('_links')

print("Links:", links.keys())
# Out:
# Links: dict_keys(['data-analysis', 'data-collection', 'data-tabulation', 'draft-content', 'qrs', 'self', 'terminology'])

# %%
# the _links collection is a common pattern for representing where you can 'go' from a location

# self represents the current resource
print("self -> ", links['self']) 

# this particular resource has sets of related resources (organised by product group)
for product_group in links.keys():
    if product_group == "self":
        continue
    for product, details in links.get(product_group).get('_links').items():
        print(f"{product_group} -> {product} -> {details}")
# Out:
# self ->  {'href': '/mdr/products', 'title': 'CDISC Library Product List', 'type': 'CDISC Library Product List'}
# data-analysis -> adam -> [{'href': '/mdr/adam/adam-2-1', 'title': 'Analysis Data Model Version 2.1', 'type': 'Foundational Model'}, {'href': '/mdr/adam/adam-adae-1-0', 'title': 'Analysis Data Model Data Structure for Adverse Event Analysis Version 1.0', 'type': 'Implementation Guide'}, {'href': '/mdr/adam/adam-occds-1-0', 'title': 'ADaM Structure for Occurrence Data (OCCDS) Version 1.0', 'type': 'Implementation Guide'}, {'href': '/mdr/adam/adam-tte-1-0', 'title': 'ADaM Basic Data Structure for Time-to-Event Analyses Version 1.0', 'type': 'Implementation Guide'}, {'href': '/mdr/adam/adamig-1-0', 'title': 'Analysis Data Model Implementation Guide Version 1.0', 'type': 'Implementation Guide'}, {'href': '/mdr/adam/adamig-1-1', 'title': 'Analysis Data Model Implementation Guide Version 1.1', 'type': 'Implementation Guide'}, {'href': '/mdr/adam/adamig-1-2', 'title': 'Analysis Data Model Implementation Guide Version 1.2', 'type': 'Implementation Guide'}]
# data-analysis -> self -> {'href': '/mdr/products/DataAnalysis', 'title': 'Product Group Data Analysis', 'type': 'CDISC Library Product Group'}
# data-collection -> cdash -> [{'href': '/mdr/cdash/1-0', 'title': 'Clinical Data Acquisition Standards Harmonization Model Version 1.0', 'type': 'Foundational Model'}, {'href': '/mdr/cdash/1-1', 'title': 'Clinical Data Acquisition Standards Harmonization Model Version 1.1', 'type': 'Foundational Model'}]
# data-collection -> cdashig -> [{'href': '/mdr/cdashig/1-1-1', 'title': 'Clinical Data Acquisition Standards Harmonization (CDASH) User Guide V1.1', 'type': 'Implementation Guide'}, {'href': '/mdr/cdashig/2-0', 'title': 'Clinical Data Acquisition Standards Harmonization Implementation Guide for Human Clinical Trials Version 2.0', 'type': 'Implementation Guide'}, {'href': '/mdr/cdashig/2-1', 'title': 'Clinical Data Acquisition Standards Harmonization Implementation Guide for Human Clinical Trials Version 2.1', 'type': 'Implementation Guide'}]
# data-collection -> self -> {'href': '/mdr/products/DataCollection', 'title': 'Product Group Data Collection', 'type': 'CDISC Library Product Group'}
# data-tabulation -> sdtm -> [{'href': '/mdr/sdtm/1-2', 'title': 'Study Data Tabulation Model Version 1.2', 'type': 'Foundational Model'}, {'href': '/mdr/sdtm/1-3', 'title': 'Study Data Tabulation Model Version 1.3', 'type': 'Foundational Model'}, {'href': '/mdr/sdtm/1-4', 'title': 'Study Data Tabulation Model Version 1.4', 'type': 'Foundational Model'}, {'href': '/mdr/sdtm/1-5', 'title': 'Study Data Tabulation Model Version 1.5', 'type': 'Foundational Model'}, {'href': '/mdr/sdtm/1-6', 'title': 'Study Data Tabulation Model Version 1.6', 'type': 'Foundational Model'}, {'href': '/mdr/sdtm/1-7', 'title': 'Study Data Tabulation Model Version 1.7', 'type': 'Foundational Model'}, {'href': '/mdr/sdtm/1-8', 'title': 'Study Data Tabulation Model Version 1.8 (Final)', 'type': 'Foundational Model'}]
# data-tabulation -> sdtmig -> [{'href': '/mdr/sdtmig/3-1-2', 'title': 'Study Data Tabulation Model Implementation Guide: Human Clinical Trials Version 3.1.2 (Final)', 'type': 'Implementation Guide'}, {'href': '/mdr/sdtmig/3-1-3', 'title': 'Study Data Tabulation Model Implementation Guide: Human Clinical Trials Version 3.1.3 (Final)', 'type': 'Implementation Guide'}, {'href': '/mdr/sdtmig/3-2', 'title': 'Study Data Tabulation Model Implementation Guide: Human Clinical Trials Version 3.2 (Final)', 'type': 'Implementation Guide'}, {'href': '/mdr/sdtmig/3-3', 'title': 'Study Data Tabulation Model Implementation Guide: Human Clinical Trials Version 3.3 (Final)', 'type': 'Implementation Guide'}, {'href': '/mdr/sdtmig/ap-1-0', 'title': 'Study Data Tabulation Model Implementation Guide: Associated Persons Version 1.0 (Final)', 'type': 'Implementation Guide'}, {'href': '/mdr/sdtmig/md-1-0', 'title': 'SDTM Implementation Guide for Medical Devices SDTMIG-MD 1.0 (Provisional)', 'type': 'Implementation Guide'}, {'href': '/mdr/sdtmig/md-1-1', 'title': 'Study Data Tabulation Model Implementation Guide for Medical Devices (SDTMIG-MD) Version 1.1', 'type': 'Implementation Guide'}, {'href': '/mdr/sdtmig/pgx-1-0', 'title': 'Study Data Tabulation Model Implementation Guide: Pharmacogenomics/Genetics Version 1.0 (Provisional)', 'type': 'Implementation Guide'}]
# data-tabulation -> self -> {'href': '/mdr/products/DataTabulation', 'title': 'Product Group Data Tabulation', 'type': 'CDISC Library Product Group'}
# data-tabulation -> sendig -> [{'href': '/mdr/sendig/3-0', 'title': 'Standard for Exchange of Nonclinical Data Implementation Guide: Nonclinical Studies Version 3.0 (Final)', 'type': 'Implementation Guide'}, {'href': '/mdr/sendig/3-1-1', 'title': 'Standard for Exchange of Nonclinical Data Implementation Guide: Nonclinical Studies Version 3.1.1 (Final)', 'type': 'Implementation Guide'}, {'href': '/mdr/sendig/3-1', 'title': 'Standard for Exchange of Nonclinical Data Implementation Guide: Nonclinical Studies Version 3.1 (Final)', 'type': 'Implementation Guide'}, {'href': '/mdr/sendig/ar-1-0', 'title': 'Standard for Exchange of Nonclinical Data Implementation Guide: Animal Rule Version 1.0 (Final)', 'type': 'Implementation Guide'}, {'href': '/mdr/sendig/dart-1-1', 'title': 'Standard for Exchange of Nonclinical Data Implementation Guide: Developmental and Reproductive Toxicology Version 1.1', 'type': 'Implementation Guide'}]
# draft-content -> adam -> [{'href': '/mdr/adam/adam-occds-1-1', 'title': 'ADaM Structure for Occurrence Data (OCCDS) Version 1.1', 'type': 'Implementation Guide'}, {'href': '/mdr/adam/adamig-1-3', 'title': 'Analysis Data Model Implementation Guide Version 1.3', 'type': 'Implementation Guide'}]
# draft-content -> sdtm -> [{'href': '/mdr/sdtm/2-0', 'title': 'Study Data Tabulation Model Version 2.0', 'type': 'Foundational Model'}]
# draft-content -> sdtmig -> [{'href': '/mdr/sdtmig/3-4', 'title': 'Study Data Tabulation Model Implementation Guide: Human Clinical Trials', 'type': 'Implementation Guide'}]
# draft-content -> self -> {'href': '/mdr/products/DraftContent', 'title': 'Product Group Draft Content', 'type': 'CDISC Library Product Group'}
# qrs -> instruments -> [{'href': '/mdr/qrs/instruments/CGI02/versions/2-1', 'title': 'Clinical Global Impression v2.1', 'type': 'QRS Instrument'}, {'href': '/mdr/qrs/instruments/PGI01/versions/1-1', 'title': 'Patient Global Impression v1.1', 'type': 'QRS Instrument'}, {'href': '/mdr/qrs/instruments/SIXMW1/versions/1-0', 'title': '6 Minute Walk Test v1.0', 'type': 'QRS Instrument'}]
# qrs -> self -> {'href': '/mdr/products/QrsInstrument', 'title': 'Product Group QRS Instrument', 'type': 'CDISC Library Product Group'}
# terminology -> packages -> [{'href': '/mdr/ct/packages/adamct-2014-09-26', 'title': 'ADaM Controlled Terminology Package 19 Effective 2014-09-26', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2015-12-18', 'title': 'ADaM Controlled Terminology Package 24 Effective 2015-12-18', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2016-03-25', 'title': 'ADaM Controlled Terminology Package 25 Effective 2016-03-25', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2016-09-30', 'title': 'ADaM Controlled Terminology Package 27 Effective 2016-09-30', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2016-12-16', 'title': 'ADaM Controlled Terminology Package 28 Effective 2016-12-16', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2017-03-31', 'title': 'ADaM Controlled Terminology Package 29 Effective 2017-03-31', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2017-09-29', 'title': 'ADaM Controlled Terminology Package 31 Effective 2017-09-29', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2018-12-21', 'title': 'ADaM Controlled Terminology Package 36 Effective 2018-12-21', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2019-03-29', 'title': 'ADaM Controlled Terminology Package 37 Effective 2019-03-29', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2019-12-20', 'title': 'ADaM Controlled Terminology Package 40 Effective 2019-12-20', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2020-03-27', 'title': 'ADaM Controlled Terminology Package 41 Effective 2020-03-27', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2020-06-26', 'title': 'ADaM Controlled Terminology Package 42 Effective 2020-06-26', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2020-11-06', 'title': 'ADaM Controlled Terminology Package 43 Effective 2020-11-06', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2014-09-26', 'title': 'CDASH Controlled Terminology Package 19 Effective 2014-09-26', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2015-03-27', 'title': 'CDASH Controlled Terminology Package 21 Effective 2015-03-27', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2016-03-25', 'title': 'CDASH Controlled Terminology Package 25 Effective 2016-03-25', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2016-09-30', 'title': 'CDASH Controlled Terminology Package 27 Effective 2016-09-30', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2016-12-16', 'title': 'CDASH Controlled Terminology Package 28 Effective 2016-12-16', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2017-09-29', 'title': 'CDASH Controlled Terminology Package 31 Effective 2017-09-29', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2018-03-30', 'title': 'CDASH Controlled Terminology Package 33 Effective 2018-03-30', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2018-06-29', 'title': 'CDASH Controlled Terminology Package 34 Effective 2018-06-29', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2018-09-28', 'title': 'CDASH Controlled Terminology Package 35 Effective 2018-09-28', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2018-12-21', 'title': 'CDASH Controlled Terminology Package 36 Effective 2018-12-21', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2019-03-29', 'title': 'CDASH Controlled Terminology Package 37 Effective 2019-03-29', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2019-06-28', 'title': 'CDASH Controlled Terminology Package 38 Effective 2019-06-28', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2019-12-20', 'title': 'CDASH Controlled Terminology Package 40 Effective 2019-12-20', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2020-11-06', 'title': 'CDASH Controlled Terminology Package 43 Effective 2020-11-06', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2020-12-18', 'title': 'CDASH Controlled Terminol ...
# terminology -> self -> {'href': '/mdr/products/Terminology', 'title': 'Product Group Terminology', 'type': 'CDISC Library Product Group'}

# %%
# the href attribute is a value you can pick to resolve the entity
href = links["terminology"]["_links"]["self"]["href"]

response = requests.get(f"{CDISC_API_URL}{href}", headers={'api-key': os.environ['CDISC_LIBRARY_API_TOKEN']})

print(response.json())
# Out:
# {'_links': {'packages': [{'href': '/mdr/ct/packages/adamct-2014-09-26', 'title': 'ADaM Controlled Terminology Package 19 Effective 2014-09-26', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2015-12-18', 'title': 'ADaM Controlled Terminology Package 24 Effective 2015-12-18', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2016-03-25', 'title': 'ADaM Controlled Terminology Package 25 Effective 2016-03-25', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2016-09-30', 'title': 'ADaM Controlled Terminology Package 27 Effective 2016-09-30', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2016-12-16', 'title': 'ADaM Controlled Terminology Package 28 Effective 2016-12-16', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2017-03-31', 'title': 'ADaM Controlled Terminology Package 29 Effective 2017-03-31', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2017-09-29', 'title': 'ADaM Controlled Terminology Package 31 Effective 2017-09-29', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2018-12-21', 'title': 'ADaM Controlled Terminology Package 36 Effective 2018-12-21', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2019-03-29', 'title': 'ADaM Controlled Terminology Package 37 Effective 2019-03-29', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2019-12-20', 'title': 'ADaM Controlled Terminology Package 40 Effective 2019-12-20', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2020-03-27', 'title': 'ADaM Controlled Terminology Package 41 Effective 2020-03-27', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2020-06-26', 'title': 'ADaM Controlled Terminology Package 42 Effective 2020-06-26', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2020-11-06', 'title': 'ADaM Controlled Terminology Package 43 Effective 2020-11-06', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2014-09-26', 'title': 'CDASH Controlled Terminology Package 19 Effective 2014-09-26', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2015-03-27', 'title': 'CDASH Controlled Terminology Package 21 Effective 2015-03-27', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2016-03-25', 'title': 'CDASH Controlled Terminology Package 25 Effective 2016-03-25', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2016-09-30', 'title': 'CDASH Controlled Terminology Package 27 Effective 2016-09-30', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2016-12-16', 'title': 'CDASH Controlled Terminology Package 28 Effective 2016-12-16', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2017-09-29', 'title': 'CDASH Controlled Terminology Package 31 Effective 2017-09-29', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2018-03-30', 'title': 'CDASH Controlled Terminology Package 33 Effective 2018-03-30', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2018-06-29', 'title': 'CDASH Controlled Terminology Package 34 Effective 2018-06-29', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2018-09-28', 'title': 'CDASH Controlled Terminology Package 35 Effective 2018-09-28', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2018-12-21', 'title': 'CDASH Controlled Terminology Package 36 Effective 2018-12-21', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2019-03-29', 'title': 'CDASH Controlled Terminology Package 37 Effective 2019-03-29', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2019-06-28', 'title': 'CDASH Controlled Terminology Package 38 Effective 2019-06-28', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2019-12-20', 'title': 'CDASH Controlled Terminology Package 40 Effective 2019-12-20', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2020-11-06', 'title': 'CDASH Controlled Terminology Package 43 Effective 2020-11-06', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2020-12-18', 'title': 'CDASH Controlled Terminology ...

# %%
# you can reuse the client authentication details by creating a Session
from requests import Session
client = Session()
client.headers['api-key'] = os.getenv("CDISC_LIBRARY_API_TOKEN")

terminology = client.get(f"{CDISC_API_URL}{href}")
print(f"Packages: {terminology.json().get('_links').get('packages')}")
# Out:
# Packages: [{'href': '/mdr/ct/packages/adamct-2014-09-26', 'title': 'ADaM Controlled Terminology Package 19 Effective 2014-09-26', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2015-12-18', 'title': 'ADaM Controlled Terminology Package 24 Effective 2015-12-18', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2016-03-25', 'title': 'ADaM Controlled Terminology Package 25 Effective 2016-03-25', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2016-09-30', 'title': 'ADaM Controlled Terminology Package 27 Effective 2016-09-30', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2016-12-16', 'title': 'ADaM Controlled Terminology Package 28 Effective 2016-12-16', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2017-03-31', 'title': 'ADaM Controlled Terminology Package 29 Effective 2017-03-31', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2017-09-29', 'title': 'ADaM Controlled Terminology Package 31 Effective 2017-09-29', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2018-12-21', 'title': 'ADaM Controlled Terminology Package 36 Effective 2018-12-21', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2019-03-29', 'title': 'ADaM Controlled Terminology Package 37 Effective 2019-03-29', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2019-12-20', 'title': 'ADaM Controlled Terminology Package 40 Effective 2019-12-20', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2020-03-27', 'title': 'ADaM Controlled Terminology Package 41 Effective 2020-03-27', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2020-06-26', 'title': 'ADaM Controlled Terminology Package 42 Effective 2020-06-26', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/adamct-2020-11-06', 'title': 'ADaM Controlled Terminology Package 43 Effective 2020-11-06', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2014-09-26', 'title': 'CDASH Controlled Terminology Package 19 Effective 2014-09-26', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2015-03-27', 'title': 'CDASH Controlled Terminology Package 21 Effective 2015-03-27', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2016-03-25', 'title': 'CDASH Controlled Terminology Package 25 Effective 2016-03-25', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2016-09-30', 'title': 'CDASH Controlled Terminology Package 27 Effective 2016-09-30', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2016-12-16', 'title': 'CDASH Controlled Terminology Package 28 Effective 2016-12-16', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2017-09-29', 'title': 'CDASH Controlled Terminology Package 31 Effective 2017-09-29', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2018-03-30', 'title': 'CDASH Controlled Terminology Package 33 Effective 2018-03-30', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2018-06-29', 'title': 'CDASH Controlled Terminology Package 34 Effective 2018-06-29', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2018-09-28', 'title': 'CDASH Controlled Terminology Package 35 Effective 2018-09-28', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2018-12-21', 'title': 'CDASH Controlled Terminology Package 36 Effective 2018-12-21', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2019-03-29', 'title': 'CDASH Controlled Terminology Package 37 Effective 2019-03-29', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2019-06-28', 'title': 'CDASH Controlled Terminology Package 38 Effective 2019-06-28', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2019-12-20', 'title': 'CDASH Controlled Terminology Package 40 Effective 2019-12-20', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2020-11-06', 'title': 'CDASH Controlled Terminology Package 43 Effective 2020-11-06', 'type': 'Terminology'}, {'href': '/mdr/ct/packages/cdashct-2020-12-18', 'title': 'CDASH Controlled Terminology Package 44 Ef ...

# %%
# let's request a particular standard (say SDTMIG version 3-2)

sdtm_ig_32 = client.get(f"{CDISC_API_URL}/mdr/sdtmig/3-2")

# %%
# decode the response
ig = sdtm_ig_32.json()

# inspect the response
print(ig.keys())
# this API call returns a class oriented structure
for ig_class in ig.get('classes'):
    # note, General Observations has no direct datasets, so we need to guard 
    if "datasets" in ig_class:
        # iterate over the datasets
        for dataset in ig_class.get('datasets'):
            # each dataset has a set of variables
            for dataset_variable in dataset.get('datasetVariables'):
                print(f"{ig_class.get('name')} -> {dataset.get('name')} -> [{dataset_variable.get('ordinal')}] {dataset_variable.get('name')}")
# Out:
# dict_keys(['_links', 'classes', 'description', 'effectiveDate', 'label', 'name', 'registrationStatus', 'source', 'version'])
# Special-Purpose -> CO -> [1] STUDYID
# Special-Purpose -> CO -> [2] DOMAIN
# Special-Purpose -> CO -> [3] RDOMAIN
# Special-Purpose -> CO -> [4] USUBJID
# Special-Purpose -> CO -> [5] COSEQ
# Special-Purpose -> CO -> [6] IDVAR
# Special-Purpose -> CO -> [7] IDVARVAL
# Special-Purpose -> CO -> [8] COREF
# Special-Purpose -> CO -> [9] COVAL
# Special-Purpose -> CO -> [10] COEVAL
# Special-Purpose -> CO -> [11] CODTC
# Special-Purpose -> DM -> [1] STUDYID
# Special-Purpose -> DM -> [2] DOMAIN
# Special-Purpose -> DM -> [3] USUBJID
# Special-Purpose -> DM -> [4] SUBJID
# Special-Purpose -> DM -> [5] RFSTDTC
# Special-Purpose -> DM -> [6] RFENDTC
# Special-Purpose -> DM -> [7] RFXSTDTC
# Special-Purpose -> DM -> [8] RFXENDTC
# Special-Purpose -> DM -> [9] RFICDTC
# Special-Purpose -> DM -> [10] RFPENDTC
# Special-Purpose -> DM -> [11] DTHDTC
# Special-Purpose -> DM -> [12] DTHFL
# Special-Purpose -> DM -> [13] SITEID
# Special-Purpose -> DM -> [14] INVID
# Special-Purpose -> DM -> [15] INVNAM
# Special-Purpose -> DM -> [16] BRTHDTC
# Special-Purpose -> DM -> [17] AGE
# Special-Purpose -> DM -> [18] AGEU
# Special-Purpose -> DM -> [19] SEX
# Special-Purpose -> DM -> [20] RACE
# Special-Purpose -> DM -> [21] ETHNIC
# Special-Purpose -> DM -> [22] ARMCD
# Special-Purpose -> DM -> [23] ARM
# Special-Purpose -> DM -> [24] ACTARMCD
# Special-Purpose -> DM -> [25] ACTARM
# Special-Purpose -> DM -> [26] COUNTRY
# Special-Purpose -> DM -> [27] DMDTC
# Special-Purpose -> DM -> [28] DMDY
# Special-Purpose -> SE -> [1] STUDYID
# Special-Purpose -> SE -> [2] DOMAIN
# Special-Purpose -> SE -> [3] USUBJID
# Special-Purpose -> SE -> [4] SESEQ
# Special-Purpose -> SE -> [5] ETCD
# Special-Purpose -> SE -> [6] ELEMENT
# Special-Purpose -> SE -> [7] SESTDTC
# Special-Purpose -> SE -> [8] SEENDTC
# Special-Purpose -> SE -> [9] TAETORD
# Special-Purpose -> SE -> [10] EPOCH
# Special-Purpose -> SE -> [11] SEUPDES
# Special-Purpose -> SV -> [1] STUDYID
# Special-Purpose -> SV -> [2] DOMAIN
# Special-Purpose -> SV -> [3] USUBJID
# Special-Purpose -> SV -> [4] VISITNUM
# Special-Purpose -> SV -> [5] VISIT
# Special-Purpose -> SV -> [6] VISITDY
# Special-Purpose -> SV -> [7] SVSTDTC
# Special-Purpose -> SV -> [8] SVENDTC
# Special-Purpose -> SV -> [9] SVSTDY
# Special-Purpose -> SV -> [10] SVENDY
# Special-Purpose -> SV -> [11] SVUPDES
# Interventions -> CM -> [1] STUDYID
# Interventions -> CM -> [2] DOMAIN
# Interventions -> CM -> [3] USUBJID
# Interventions -> CM -> [4] CMSEQ
# Interventions -> CM -> [5] CMGRPID
# Interventions -> CM -> [6] CMSPID
# Interventions -> CM -> [7] CMTRT
# Interventions -> CM -> [8] CMMODIFY
# Interventions -> CM -> [9] CMDECOD
# Interventions -> CM -> [10] CMCAT
# Interventions -> CM -> [11] CMSCAT
# Interventions -> CM -> [12] CMPRESP
# Interventions -> CM -> [13] CMOCCUR
# Interventions -> CM -> [14] CMSTAT
# Interventions -> CM -> [15] CMREASND
# Interventions -> CM -> [16] CMINDC
# Interventions -> CM -> [17] CMCLAS
# Interventions -> CM -> [18] CMCLASCD
# Interventions -> CM -> [19] CMDOSE
# Interventions -> CM -> [20] CMDOSTXT
# Interventions -> CM -> [21] CMDOSU
# Interventions -> CM -> [22] CMDOSFRM
# Interventions -> CM -> [23] CMDOSFRQ
# Interventions -> CM -> [24] CMDOSTOT
# Interventions -> CM -> [25] CMDOSRGM
# Interventions -> CM -> [26] CMROUTE
# Interventions -> CM -> [27] CMSTDTC
# Interventions -> CM -> [28] CMENDTC
# Interventions -> CM -> [29] CMSTDY
# Interventions -> CM -> [30] CMENDY
# Interventions -> CM -> [31] CMDUR
# Interventions -> CM -> [32] CMSTRF
# Interventions -> CM -> [33] CMENRF
# Interventions -> CM -> [34] CMSTRTPT
# Interventions -> CM -> [35] CMSTTPT
# Interventions -> CM -> [36] CMENRTPT
# Interventions -> CM -> [37] CMENTPT
# Interventions -> EX -> [1] STUDYID
# Interventions -> EX -> [2] DOMAIN
# Interventions -> EX -> [3] USUBJID
# Interventions -> EX -> [4] EXSEQ
# Interventions -> EX -> [5] EXGRPID
# Interventions -> EX -> [6] EXREFID
# Interventions -> EX -> [7] EXSPID
# Interventions -> EX -> [8] EXLNKID
# Interventions -> EX -> [9] EXLNKGRP
# Interventions -> EX -> [10] EXTRT
# Interventions -> EX -> [11] EXCAT
# Interventions -> EX -> [12] EXSCAT
# Interventions -> EX -> [13] EXDOSE
# Interventions -> EX -> [14] EXDOSTXT
# Interventions -> EX -> [15] EXDOSU
# Interventions -> EX -> [16] EXDOSFRM
# Interventions -> EX -> [17] EXDOSFRQ
# Interventions -> EX -> [18] EXDOSRGM
# Interventions -> EX -> [19] EXROUTE
# Interventions -> EX -> [20] EXLOT
# Interventions -> EX -> [21] EXLOC
# Interventions -> EX -> [22] EXLAT
# Interventions -> EX -> [23] EXDIR
# Interventions -> EX -> [24] EXFAST
# Interventions -> EX -> [25] EXADJ
# Interventions -> EX -> [26] EPOCH
# Interventions -> EX -> [27] EXSTDTC
# Interventions -> EX -> [28] EXENDTC
# Interventions -> EX -> [29] EXSTDY
# Interventions -> EX -> [30] EXENDY
# Interventions -> EX -> [31] EXDUR
# Interventions -> EX -> [32] EXTPT
# Interventions -> EX -> [33] EXTPTNUM
# Interventions -> EX -> [34] EXELTM
# Interventions -> EX -> [35] EXTPTREF
# Interventions -> EX -> [36] EXRFTDTC
# Interventions -> EC -> [1] STUDYID
# Interventions -> EC -> [2] DOMAIN
# Interventions -> EC -> [3] USUBJID
# Interventions -> EC -> [4] ECSEQ
# Interventions -> EC -> [5] ECGRPID
# Interventions -> EC -> [6] ECREFID
# Interventions -> EC -> [7] ECSPID
# Interventions -> EC -> [8] ECLNKID
# Interventions -> EC -> [9] ECLNKGRP
# Interventions -> EC -> [10] ECTRT
# Interventions -> EC -> [11] ECMOOD
# Interventions -> EC -> [12] ECCAT
# Interventions -> EC -> [13] ECSCAT
# Interventions -> EC -> [14] ECPRESP
# Interventions -> EC -> [15] ECOCCUR
# Interventions -> EC -> [16] ECDOSE
# Interventions -> EC -> [17] ECDOSTXT
# Interventions -> EC -> [18] ECDOSU
# Interventions -> EC -> [19] ECDOSFRM
# Interventions -> EC -> [20] ECDOSFRQ
# Interventions -> EC -> [21] ECDOSTOT
# Interventions -> EC -> [22] ECDOSRGM
# Interventions -> EC -> [23] ECROUTE
# Interventions -> EC -> [24] ECLOT
# Interventions -> EC -> [25] ECLOC
# Interventions -> EC -> [26] ECLAT
# Interventions -> EC -> [27] ECDIR
# Interventions -> EC -> [28] ECPORTOT
# Interventions -> EC -> [29] ECFAST
# Interventions -> EC -> [30] ECPSTRG
# Interventions -> EC -> [31] ECPSTRGU
# Interventions -> EC -> [32] ECADJ
# Interventions -> EC -> [33] EPOCH
# Interventions -> EC -> [34] ECSTDTC
# Interventions -> EC -> [35] ECENDTC
# Interventions -> EC -> [36] ECSTDY
# Interventions -> EC -> [37] ECENDY
# Interventions -> EC -> [38] ECDUR
# Interventions -> EC -> [39] ECTPT
# Interventions -> EC -> [40] ECTPTNUM
# Interventions -> EC -> [41] ECELTM
# Interventions -> EC -> [42] ECTPTREF
# Interventions -> EC -> [43] ECRFTDTC
# Interventions -> PR -> [1] STUDYID
# Interventions -> PR -> [2] DOMAIN
# Interventions -> PR -> [3] USUBJID
# Interventions -> PR -> [4] PRSEQ
# Interventions -> PR -> [5] PRGRPID
# Interventions -> PR -> [6] PRSPID
# Interventions -> PR -> [7] PRLNKID
# Interventions -> PR -> [8] PRLNKGRP
# Interventions -> PR -> [9] PRTRT
# Interventions -> PR -> [10] PRDECOD
# Interventions -> PR -> [11] PRCAT
# Interventions -> PR -> [12] PRSCAT
# Interventions -> PR -> [13] PRPRESP
# Interventions -> PR -> [14] PROCCUR
# Interventions -> PR -> [15] PRINDC
# Interventions -> PR -> [16] PRDOSE
# Interventions -> PR -> [17] PRDOSTXT
# Interventions -> PR -> [18] PRDOSU
# Interventions -> PR -> [19] PRDOSFRM
# Interventions -> PR -> [20] PRDOSFRQ
# Interventions -> PR -> [21] PRDOSRGM
# Interventions -> PR -> [22] PRROUTE
# Interventions -> PR -> [23] PRLOC
# Interventions -> PR -> [24] PRLAT
# Interventions -> PR -> [25] PRDIR
# Interventions -> PR -> [26] PRPORTOT
# Interventions -> PR -> [27] VISITNUM
# Interventions -> PR -> [28] VISIT
# Interventions -> PR -> [29] VISITDY
# Interventions -> PR -> [30] PRSTDTC
# Interventions -> PR -> [31] PRENDTC
# Interventions -> PR -> [32] PRSTDY
# Interventions -> PR -> [33] PRENDY
# Interventions -> PR -> [34] PRDUR
# Interventions -> PR -> [35] PRTPT
# Interventions -> PR -> [36] PRTPTNUM
# Interventions -> PR -> [37] PRELTM
# Interventions -> PR -> [38] PRTPTREF
# Interventions -> PR -> [39] PRRFTDTC
# Interventions -> PR -> [40] PRSTRTPT
# Interventions -> PR -> [41] PRSTTPT
# Interventions -> PR -> [42] PRENRTPT
# Interventions -> PR -> [43] PRENTPT
# Interventions -> SU -> [1] STUDYID
# Interventions -> SU -> [2] DOMAIN
# Interventions -> SU -> [3] USUBJID
# Interventions -> SU -> [4] SUSEQ
# Interventions -> SU -> [5] SUGRPID
# Interventions -> SU -> [6] SUSPID
# Interventions -> SU -> [7] SUTRT
# Interventions -> SU -> [8] SUMODIFY
# Interventions -> SU -> [9] SUDECOD
# Interventions -> SU -> [10] SUCAT
# Interventions -> SU -> [11] SUSCAT
# Interventions -> SU -> [12] SUPRESP
# Interventions -> SU -> [13] SUOCCUR
# Interventions -> SU -> [14] SUSTAT
# Interventions -> SU -> [15] SUREASND
# Interventions -> SU -> [16] SUCLAS
# Interventions -> SU -> [17] SUCLASCD
# Interventions -> SU -> [18] SUDOSE
# Interventions -> SU -> [19] SUDOSTXT
# Interventions -> SU -> [20] SUDOSU
# Interventions -> SU -> [21] SUDOSFRM
# Interventions -> SU -> [22] SUDOSFRQ
# Interventions -> SU -> [23] SUDOSTOT
# Interventions -> SU -> [24] SUROUTE
# Interventions -> SU -> [25] SUSTDTC
# Interventions -> SU -> [26] SUENDTC
# Interventions -> SU -> [27] SUSTDY
# Interventions -> SU -> [28] SUENDY
# Interventions -> SU -> [29] SUDUR
# Interventions -> SU -> [30] SUSTRF
# Interventions -> SU -> [31] SUENRF
# Interventions -> SU -> [32] SUSTRTPT
# Interventions -> SU -> [33] SUSTTPT
# Interventions -> SU -> [34] SUENRTPT
# Interventions -> SU -> [35] SUENTPT
# Events -> AE -> [1] STUDYID
# Events -> AE -> [2] DOMAIN
# Events -> AE -> [3] USUBJID
# Events -> AE -> [4] AESEQ
# Events -> AE -> [5] AEGRPID
# Events -> AE -> [6] AEREFID
# Events -> AE -> [7] AESPID
# Events -> AE -> [8] AETERM
# Events -> AE -> [9] AEMODIFY
# Events -> AE -> [10] AELLT
# Events -> AE -> [11] AELLTCD
# Events -> AE -> [12] AEDECOD
# Events -> AE -> [13] AEPTCD
# Events -> AE -> [14] AEHLT
# Events -> AE -> [15] AEHLTCD
# Events -> AE -> [16] AEHLGT
# Events -> AE -> [17] AEHLGTCD
# Events -> AE -> [18] AECAT
# Events -> AE -> [19] AESCAT
# Events -> AE -> [20] AEPRESP
# Events -> AE -> [21] AEBODSYS
# Events -> AE -> [22] AEBDSYCD
# Events -> AE -> [23] AESOC
# Events -> AE -> [24] AESOCCD
# Events -> AE -> [25] AELOC
# Events -> AE -> [26] AESEV
# Events -> AE -> [27] AESER
# Events -> AE -> [28] AEACN
# Events -> AE -> [29] AEACNOTH
# Events -> AE -> [30] AEREL
# Events -> AE -> [31] AERELNST
# Events -> AE -> [32] AEPATT
# Events -> AE -> [33] AEOUT
# Events -> AE -> [34] AESCAN
# Events -> AE -> [35] AESCONG
# Events -> AE -> [36] AESDISAB
# Events -> AE -> [37] AESDTH
# Events -> AE -> [38] AESHOSP
# Events -> AE -> [39] AESLIFE
# Events -> AE -> [40] AESOD
# Events -> AE -> [41] AESMIE
# Events -> AE -> [42] AECONTRT
# Events -> AE -> [43] AETOXGR
# Events -> AE -> [44] AESTDTC
# Events -> AE -> [45] AEENDTC
# Events -> AE -> [46] AESTDY
# Events -> AE -> [47] AEENDY
# Events -> AE -> [48] AEDUR
# Events -> AE -> [49] AEENRF
# Events -> AE -> [50] AEENRTPT
# Events -> AE -> [51] AEENTPT
# Events -> CE -> [1] STUDYID
# Events -> CE -> [2] DOMAIN
# Events -> CE -> [3] USUBJID
# Events -> CE -> [4] CESEQ
# Events -> CE -> [5] CEGRPID
# Events -> CE -> [6] CEREFID
# Events -> CE -> [7] CESPID
# Events -> CE -> [8] CETERM
# Events -> CE -> [9] CEDECOD
# Events -> CE -> [10] CECAT
# Events -> CE -> [11] CESCAT
# Events -> CE -> [12] CEPRESP
# Events -> CE -> [13] CEOCCUR
# Events -> CE -> [14] CESTAT
# Events -> CE -> [15] CEREASND
# Events -> CE -> [16] CEBODSYS
# Events -> CE -> [17] CESEV
# Events -> CE -> [18] CEDTC
# Events -> CE -> [19] CESTDTC
# Events -> CE -> [20] CEENDTC
# Events -> CE -> [21] CEDY
# Events -> CE -> [22] CESTRF
# Events -> CE -> [23] CEENRF
# Events -> CE -> [24] CESTRTPT
# Events -> CE -> [25] CESTTPT
# Events -> CE -> [26] CEENRTPT
# Events -> CE -> [27] CEENTPT
# Events -> DS -> [1] STUDYID
# Events -> DS -> [2] DOMAIN
# Events -> DS -> [3] USUBJID
# Events -> DS -> [4] DSSEQ
# Events -> DS -> [5] DSGRPID
# Events -> DS -> [6] DSREFID
# Events -> DS -> [7] DSSPID
# Events -> DS -> [8] DSTERM
# Events -> DS -> [9] DSDECOD
# Events -> DS -> [10] DSCAT
# Events -> DS -> [11] DSSCAT
# Events -> DS -> [12] EPOCH
# Events -> DS -> [13] DSDTC
# Events -> DS -> [14] DSSTDTC
# Events -> DS -> [15] DSSTDY
# Events -> DV -> [1] STUDYID
# Events -> DV -> [2] DOMAIN
# Events -> DV -> [3] USUBJID
# Events -> DV -> [4] DVSEQ
# Events -> DV -> [5] DVREFID
# Events -> DV -> [6] DVSPID
# Events -> DV -> [7] DVTERM
# Events -> DV -> [8] DVDECOD
# Events -> DV -> [9] DVCAT
# Events -> DV -> [10] DVSCAT
# Events -> DV -> [11] EPOCH
# Events -> DV -> [12] DVSTDTC
# Events -> DV -> [13] DVENDTC
# Events -> HO -> [1] STUDYID
# Events -> HO -> [2] DOMAIN
# Events -> HO -> [3] USUBJID
# Events -> HO -> [4] HOSEQ
# Events -> HO -> [5] HOGRPID
# Events -> HO -> [6] HOREFID
# Events -> HO -> [7] HOSPID
# Events -> HO -> [8] HOTERM
# Events -> HO -> [9] HODECOD
# Events -> HO -> [10] HOCAT
# Events -> HO -> [11] HOSCAT
# Events -> HO -> [12] HOPRESP
# Events -> HO -> [13] HOOCCUR
# Events -> HO -> [14] HOSTAT
# Events -> HO -> [15] HOREASND
# Events -> HO -> [16] HODTC
# Events -> HO -> [17] HOSTDTC
# Events -> HO -> [18] HOENDTC
# Events -> HO -> [19] HODY
# Events -> HO -> [20] HOSTDY
# Events -> HO -> [21] HOENDY
# Events -> HO -> [22] HODUR
# Events -> HO -> [23] HOSTRTPT
# Events -> HO -> [24] HOSTTPT
# Events -> HO -> [25] HOENRTPT
# Events -> HO -> [26] HOENTPT
# Events -> MH -> [1] STUDYID
# Events -> MH -> [2] DOMAIN
# Events -> MH -> [3] USUBJID
# Events -> MH -> [4] MHSEQ
# Events -> MH -> [5] MHGRPID
# Events -> MH -> [6] MHREFID
# Events -> MH -> [7] MHSPID
# Events -> MH -> [8] MHTERM
# Events -> MH -> [9] MHMODIFY
# Events -> MH -> [10] MHDECOD
# Events -> MH -> [11] MHCAT
# Events -> MH -> [12] MHSCAT
# Events -> MH -> [13] MHPRESP
# Events -> MH -> [14] MHOCCUR
# Events -> MH -> [15] MHSTAT
# Events -> MH -> [16] MHREASND
# Events -> MH -> [17] MHBODSYS
# Events -> MH -> [18] MHDTC
# Events -> MH -> [19] MHSTDTC
# Events -> MH -> [20] MHENDTC
# Events -> MH -> [21] MHDY
# Events -> MH -> [22] MHENRF
# Events -> MH -> [23] MHENRTPT
# Events -> MH -> [24] MHENTPT
# Findings -> DA -> [1] STUDYID
# Findings -> DA -> [2] DOMAIN
# Findings -> DA -> [3] USUBJID
# Findings -> DA -> [4] DASEQ
# Findings -> DA -> [5] DAGRPID
# Findings -> DA -> [6] DAREFID
# Findings -> DA -> [7] DASPID
# Findings -> DA -> [8] DATESTCD
# Findings -> DA -> [9] DATEST
# Findings -> DA -> [10] DACAT
# Findings -> DA -> [11] DASCAT
# Findings -> DA -> [12] DAORRES
# Findings -> DA -> [13] DAORRESU
# Findings -> DA -> [14] DASTRESC
# Findings -> DA -> [15] DASTRESN
# Findings -> DA -> [16] DASTRESU
# Findings -> DA -> [17] DASTAT
# Findings -> DA -> [18] DAREASND
# Findings -> DA -> [19] VISITNUM
# Findings -> DA -> [20] VISIT
# Findings -> DA -> [21] VISITDY
# Findings -> DA -> [22] DADTC
# Findings -> DA -> [23] DADY
# Findings -> DD -> [1] STUDYID
# Findings -> DD -> [2] DOMAIN
# Findings -> DD -> [3] USUBJID
# Findings -> DD -> [4] DDSEQ
# Findings -> DD -> [5] DDTESTCD
# Findings -> DD -> [6] DDTEST
# Findings -> DD -> [7] DDORRES
# Findings -> DD -> [8] DDSTRESC
# Findings -> DD -> [9] DDRESCAT
# Findings -> DD -> [10] DDEVAL
# Findings -> DD -> [11] DDDTC
# Findings -> DD -> [12] DDDY
# Findings -> EG -> [1] STUDYID
# Findings -> EG -> [2] DOMAIN
# Findings -> EG -> [3] USUBJID
# Findings -> EG -> [4] EGSEQ
# Findings -> EG -> [5] EGGRPID
# Findings -> EG -> [6] EGREFID
# Findings -> EG -> [7] EGSPID
# Findings -> EG -> [8] EGTESTCD
# Findings -> EG -> [9] EGTEST
# Findings -> EG -> [10] EGCAT
# Findings -> EG -> [11] EGSCAT
# Findings -> EG -> [12] EGPOS
# Findings -> EG -> [13] EGORRES
# Findings -> EG -> [14] EGORRESU
# Findings -> EG -> [15] EGSTRESC
# Findings -> EG -> [16] EGSTRESN
# Findings -> EG -> [17] EGSTRESU
# Findings -> EG -> [18] EGSTAT
# Findings -> EG -> [19] EGREASND
# Findings -> EG -> [20] EGXFN
# Findings -> EG -> [21] EGNAM
# Findings -> EG -> [22] EGLEAD
# Findings -> EG -> [23] EGMETHOD
# Findings -> EG -> [24] EGBLFL
# Findings -> EG -> [25] EGDRVFL
# Findings -> EG -> [26] EGEVAL
# Findings -> EG -> [27] VISITNUM
# Findings -> EG -> [28] VISIT
# Findings -> EG -> [29] VISITDY
# Findings -> EG -> [30] EGDTC
# Findings -> EG -> [31] EGDY
# Findings -> EG -> [32] EGTPT
# Findings -> EG -> [33] EGTPTNUM
# Findings -> EG -> [34] EGELTM
# Findings -> EG -> [35] EGTPTREF
# Findings -> EG -> [36] EGRFTDTC
# Findings -> IE -> [1] STUDYID
# Findings -> IE -> [2] DOMAIN
# Findings -> IE -> [3] USUBJID
# Findings -> IE -> [4] IESEQ
# Findings -> IE -> [5] IESPID
# Findings -> IE -> [6] IETESTCD
# Findings -> IE -> [7] IETEST
# Findings -> IE -> [8] IECAT
# Findings -> IE -> [9] IESCAT
# Findings -> IE -> [10] IEORRES
# Findings -> IE -> [11] IESTRESC
# Findings -> IE -> [12] VISITNUM
# Findings -> IE -> [13] VISIT
# Findings -> IE -> [14] VISITDY
# Findings -> IE -> [15] IEDTC
# Findings -> IE -> [16] IEDY
# Findings -> IS -> [1] STUDYID
# Findings -> IS -> [2] DOMAIN
# Findings -> IS -> [3] USUBJID
# Findings -> IS -> [4] ISSEQ
# Findings -> IS -> [5] ISGRPID
# Findings -> IS -> [6] ISREFID
# Findings -> IS -> [7] ISSPID
# Findings -> IS -> [8] ISTESTCD
# Findings -> IS -> [9] ISTEST
# Findings -> IS -> [10] ISCAT
# Findings -> IS -> [11] ISSCAT
# Findings -> IS -> [12] ISORRES
# Findings -> IS -> [13] ISORRESU
# Findings -> IS -> [14] ISSTRESC
# Findings -> IS -> [15] ISSTRESN
# Findings -> IS -> [16] ISSTRESU
# Findings -> IS -> [17] ISSTAT
# Findings -> IS -> [18] ISREASND
# Findings -> IS -> [19] ISNAM
# Findings -> IS -> [20] ISSPEC
# Findings -> IS -> [21] ISMETHOD
# Findings -> IS -> [22] ISBLFL
# Findings -> IS -> [23] ISLLOQ
# Findings -> IS -> [24] VISITNUM
# Findings -> IS -> [25] VISIT
# Findings -> IS -> [26] VISITDY
# Findings -> IS -> [27] ISDTC
# Findings -> IS -> [28] ISDY
# Findings -> LB -> [1] STUDYID
# Findings -> LB -> [2] DOMAIN
# Findings -> LB -> [3] USUBJID
# Findings -> LB -> [4] LBSEQ
# Findings -> LB -> [5] LBGRPID
# Findings -> LB -> [6] LBREFID
# Findings -> LB -> [7] LBSPID
# Findings -> LB -> [8] LBTESTCD
# Findings -> LB -> [9] LBTEST
# Findings -> LB -> [10] LBCAT
# Findings -> LB -> [11] LBSCAT
# Findings -> LB -> [12] LBORRES
# Findings -> LB -> [13] LBORRESU
# Findings -> LB -> [14] LBORNRLO
# Findings -> LB -> [15] LBORNRHI
# Findings -> LB -> [16] LBSTRESC
# Findings -> LB -> [17] LBSTRESN
# Findings -> LB -> [18] LBSTRESU
# Findings -> LB -> [19] LBSTNRLO
# Findings -> LB -> [20] LBSTNRHI
# Findings -> LB -> [21] LBSTNRC
# Findings -> LB -> [22] LBNRIND
# Findings -> LB -> [23] LBSTAT
# Findings -> LB -> [24] LBREASND
# Findings -> LB -> [25] LBNAM
# Findings -> LB -> [26] LBLOINC
# Findings -> LB -> [27] LBSPEC
# Findings -> LB -> [28] LBSPCCND
# Findings -> LB -> [29] LBMETHOD
# Findings -> LB -> [30] LBBLFL
# Findings -> LB -> [31] LBFAST
# Findings -> LB -> [32] LBDRVFL
# Findings -> LB -> [33] LBTOX
# Findings -> LB -> [34] LBTOXGR
# Findings -> LB -> [35] VISITNUM
# Findings -> LB -> [36] VISIT
# Findings -> LB -> [37] VISITDY
# Findings -> LB -> [38] LBDTC
# Findings -> LB -> [39] LBENDTC
# Findings -> LB -> [40] LBDY
# Findings -> LB -> [41] LBTPT
# Findings -> LB -> [42] LBTPTNUM
# Findings -> LB -> [43] LBELTM
# Findings -> LB -> [44] LBTPTREF
# Findings -> LB -> [45] LBRFTDTC
# Findings -> MB -> [1] STUDYID
# Findings -> MB -> [2] DOMAIN
# Findings -> MB -> [3] USUBJID
# Findings -> MB -> [4] MBSEQ
# Findings -> MB -> [5] MBGRPID
# Findings -> MB -> [6] MBREFID
# Findings -> MB -> [7] MBSPID
# Findings -> MB -> [8] MBTESTCD
# Findings -> MB -> [9] MBTEST
# Findings -> MB -> [10] MBCAT
# Findings -> MB -> [11] MBSCAT
# Findings -> MB -> [12] MBORRES
# Findings -> MB -> [13] MBORRESU
# Findings -> MB -> [14] MBSTRESC
# Findings -> MB -> [15] MBSTRESN
# Findings -> MB -> [16] MBSTRESU
# Findings -> MB -> [17] MBRESCAT
# Findings -> MB -> [18] MBSTAT
# Findings -> MB -> [19] MBREASND
# Findings -> MB -> [20] MBNAM
# Findings -> MB -> [21] MBLOINC
# Findings -> MB -> [22] MBSPEC
# Findings -> MB -> [23] MBSPCCND
# Findings -> MB -> [24] MBLOC
# Findings -> MB -> [25] MBMETHOD
# Findings -> MB -> [26] MBBLFL
# Findings -> MB -> [27] MBDRVFL
# Findings -> MB -> [28] VISITNUM
# Findings -> MB -> [29] VISIT
# Findings -> MB -> [30] VISITDY
# Findings -> MB -> [31] MBDTC
# Findings -> MB -> [32] MBDY
# Findings -> MB -> [33] MBTPT
# Findings -> MB -> [34] MBTPTNUM
# Findings -> MB -> [35] MBELTM
# Findings -> MB -> [36] MBTPTREF
# Findings -> MB -> [37] MBRFTDTC
# Findings -> MS -> [1] STUDYID
# Findings -> MS -> [2] DOMAIN
# Findings -> MS -> [3] USUBJID
# Findings -> MS -> [4] MSSEQ
# Findings -> MS -> [5] MSGRPID
# Findings -> MS -> [6] MSREFID
# Findings -> MS -> [7] MSSPID
# Findings -> MS -> [8] MSTESTCD
# Findings -> MS -> [9] MSTEST
# Findings -> MS -> [10] MSCAT
# Findings -> MS -> [11] MSSCAT
# Findings -> MS -> [12] MSORRES
# Findings -> MS -> [13] MSORRESU
# Findings -> MS -> [14] MSSTRESC
# Findings -> MS -> [15] MSSTRESN
# Findings -> MS -> [16] MSSTRESU
# Findings -> MS -> [17] MSRESCAT
# Findings -> MS -> [18] MSSTAT
# Findings -> MS -> [19] MSREASND
# Findings -> MS -> [20] MSNAM
# Findings -> MS -> [21] MSLOINC
# Findings -> MS -> [22] MSMETHOD
# Findings -> MS -> [23] MSBLFL
# Findings -> MS -> [24] MSDRVFL
# Findings -> MS -> [25] VISITNUM
# Findings -> MS -> [26] VISIT
# Findings -> MS -> [27] VISITDY
# Findings -> MS -> [28] MSDTC
# Findings -> MS -> [29] MSDY
# Findings -> MS -> [30] MSTPT
# Findings -> MS -> [31] MSTPTNUM
# Findings -> MS -> [32] MSELTM
# Findings -> MS -> [33] MSTPTREF
# Findings -> MI -> [1] STUDYID
# Findings -> MI -> [2] DOMAIN
# Findings -> MI -> [3] USUBJID
# Findings -> MI -> [4] MISEQ
# Findings -> MI -> [5] MIGRPID
# Findings -> MI -> [6] MIREFID
# Findings -> MI -> [7] MISPID
# Findings -> MI -> [8] MITESTCD
# Findings -> MI -> [9] MITEST
# Findings -> MI -> [10] MITSTDTL
# Findings -> MI -> [11] MICAT
# Findings -> MI -> [12] MISCAT
# Findings -> MI -> [13] MIORRES
# Findings -> MI -> [14] MIORRESU
# Findings -> MI -> [15] MISTRESC
# Findings -> MI -> [16] MISTRESN
# Findings -> MI -> [17] MISTRESU
# Findings -> MI -> [18] MIRESCAT
# Findings -> MI -> [19] MISTAT
# Findings -> MI -> [20] MIREASND
# Findings -> MI -> [21] MINAM
# Findings -> MI -> [22] MISPEC
# Findings -> MI -> [23] MISPCCND
# Findings -> MI -> [24] MILOC
# Findings -> MI -> [25] MILAT
# Findings -> MI -> [26] MIDIR
# Findings -> MI -> [27] MIMETHOD
# Findings -> MI -> [28] MIBLFL
# Findings -> MI -> [29] MIEVAL
# Findings -> MI -> [30] VISITNUM
# Findings -> MI -> [31] VISIT
# Findings -> MI -> [32] VISITDY
# Findings -> MI -> [33] MIDTC
# Findings -> MI -> [34] MIDY
# Findings -> MO -> [1] STUDYID
# Findings -> MO -> [2] DOMAIN
# Findings -> MO -> [3] USUBJID
# Findings -> MO -> [4] MOSEQ
# Findings -> MO -> [5] MOGRPID
# Findings -> MO -> [6] MOREFID
# Findings -> MO -> [7] MOSPID
# Findings -> MO -> [8] MOLNKID
# Findings -> MO -> [9] MOTESTCD
# Findings -> MO -> [10] MOTEST
# Findings -> MO -> [11] MOCAT
# Findings -> MO -> [12] MOSCAT
# Findings -> MO -> [13] MOPOS
# Findings -> MO -> [14] MOORRES
# Findings -> MO -> [15] MOORRESU
# Findings -> MO -> [16] MOSTRESC
# Findings -> MO -> [17] MOSTRESN
# Findings -> MO -> [18] MOSTRESU
# Findings -> MO -> [19] MOSTAT
# Findings -> MO -> [20] MOREASND
# Findings -> MO -> [21] MOXFN
# Findings -> MO -> [22] MONAM
# Findings -> MO -> [23] MOLOC
# Findings -> MO -> [24] MOLAT
# Findings -> MO -> [25] MODIR
# Findings -> MO -> [26] MOPORTOT
# Findings -> MO -> [27] MOMETHOD
# Findings -> MO -> [28] MOANMETH
# Findings -> MO -> [29] MOBLFL
# Findings -> MO -> [30] MODRVFL
# Findings -> MO -> [31] MOEVAL
# Findings -> MO -> [32] VISITNUM
# Findings -> MO -> [33] VISIT
# Findings -> MO -> [34] VISITDY
# Findings -> MO -> [35] MODTC
# Findings -> MO -> [36] MODY
# Findings -> MO -> [37] MOTPT
# Findings -> MO -> [38] MOTPTNUM
# Findings -> MO -> [39] MOELTM
# Findings -> MO -> [40] MOTPTREF
# Findings -> MO -> [41] MORFTDTC
# Findings -> PC -> [1] STUDYID
# Findings -> PC -> [2] DOMAIN
# Findings -> PC -> [3] USUBJID
# Findings -> PC -> [4] PCSEQ
# Findings -> PC -> [5] PCGRPID
# Findings -> PC -> [6] PCREFID
# Findings -> PC -> [7] PCSPID
# Findings -> PC -> [8] PCTESTCD
# Findings -> PC -> [9] PCTEST
# Findings -> PC -> [10] PCCAT
# Findings -> PC -> [11] PCSCAT
# Findings -> PC -> [12] PCORRES
# Findings -> PC -> [13] PCORRESU
# Findings -> PC -> [14] PCSTRESC
# Findings -> PC -> [15] PCSTRESN
# Findings -> PC -> [16] PCSTRESU
# Findings -> PC -> [17] PCSTAT
# Findings -> PC -> [18] PCREASND
# Findings -> PC -> [19] PCNAM
# Findings -> PC -> [20] PCSPEC
# Findings -> PC -> [21] PCSPCCND
# Findings -> PC -> [22] PCMETHOD
# Findings -> PC -> [23] PCFAST
# Findings -> PC -> [24] PCDRVFL
# Findings -> PC -> [25] PCLLOQ
# Findings -> PC -> [26] PCULOQ
# Findings -> PC -> [27] VISITNUM
# Findings -> PC -> [28] VISIT
# Findings -> PC -> [29] VISITDY
# Findings -> PC -> [30] PCDTC
# Findings -> PC -> [31] PCENDTC
# Findings -> PC -> [32] PCDY
# Findings -> PC -> [33] PCTPT
# Findings -> PC -> [34] PCTPTNUM
# Findings -> PC -> [35] PCELTM
# Findings -> PC -> [36] PCTPTREF
# Findings -> PC -> [37] PCRFTDTC
# Findings -> PC -> [38] PCEVLINT
# Findings -> PP -> [1] STUDYID
# Findings -> PP -> [2] DOMAIN
# Findings -> PP -> [3] USUBJID
# Findings -> PP -> [4] PPSEQ
# Findings -> PP -> [5] PPGRPID
# Findings -> PP -> [6] PPTESTCD
# Findings -> PP -> [7] PPTEST
# Findings -> PP -> [8] PPCAT
# Findings -> PP -> [9] PPSCAT
# Findings -> PP -> [10] PPORRES
# Findings -> PP -> [11] PPORRESU
# Findings -> PP -> [12] PPSTRESC
# Findings -> PP -> [13] PPSTRESN
# Findings -> PP -> [14] PPSTRESU
# Findings -> PP -> [15] PPSTAT
# Findings -> PP -> [16] PPREASND
# Findings -> PP -> [17] PPSPEC
# Findings -> PP -> [18] PPDTC
# Findings -> PP -> [19] PPRFTDTC
# Findings -> PP -> [20] PPSTINT
# Findings -> PP -> [21] PPENINT
# Findings -> PE -> [1] STUDYID
# Findings -> PE -> [2] DOMAIN
# Findings -> PE -> [3] USUBJID
# Findings -> PE -> [4] PESEQ
# Findings -> PE -> [5] PEGRPID
# Findings -> PE -> [6] PESPID
# Findings -> PE -> [7] PETESTCD
# Findings -> PE -> [8] PETEST
# Findings -> PE -> [9] PEMODIFY
# Findings -> PE -> [10] PECAT
# Findings -> PE -> [11] PESCAT
# Findings -> PE -> [12] PEBODSYS
# Findings -> PE -> [13] PEORRES
# Findings -> PE -> [14] PEORRESU
# Findings -> PE -> [15] PESTRESC
# Findings -> PE -> [16] PESTAT
# Findings -> PE -> [17] PEREASND
# Findings -> PE -> [18] PELOC
# Findings -> PE -> [19] PEMETHOD
# Findings -> PE -> [20] PEEVAL
# Findings -> PE -> [21] VISITNUM
# Findings -> PE -> [22] VISIT
# Findings -> PE -> [23] VISITDY
# Findings -> PE -> [24] PEDTC
# Findings -> PE -> [25] PEDY
# Findings -> QS -> [1] STUDYID
# Findings -> QS -> [2] DOMAIN
# Findings -> QS -> [3] USUBJID
# Findings -> QS -> [4] QSSEQ
# Findings -> QS -> [5] QSGRPID
# Findings -> QS -> [6] QSSPID
# Findings -> QS -> [7] QSTESTCD
# Findings -> QS -> [8] QSTEST
# Findings -> QS -> [9] QSCAT
# Findings -> QS -> [10] QSSCAT
# Findings -> QS -> [11] QSORRES
# Findings -> QS -> [12] QSORRESU
# Findings -> QS -> [13] QSSTRESC
# Findings -> QS -> [14] QSSTRESN
# Findings -> QS -> [15] QSSTRESU
# Findings -> QS -> [16] QSSTAT
# Findings -> QS -> [17] QSREASND
# Findings -> QS -> [18] QSBLFL
# Findings -> QS -> [19] QSDRVFL
# Findings -> QS -> [20] QSEVAL
# Findings -> QS -> [21] VISITNUM
# Findings -> QS -> [22] VISIT
# Findings -> QS -> [23] VISITDY
# Findings -> QS -> [24] QSDTC
# Findings -> QS -> [25] QSDY
# Findings -> QS -> [26] QSTPT
# Findings -> QS -> [27] QSTPTNUM
# Findings -> QS -> [28] QSELTM
# Findings -> QS -> [29] QSTPTREF
# Findings -> QS -> [30] QSRFTDTC
# Findings -> QS -> [31] QSEVLINT
# Findings -> RP -> [1] STUDYID
# Findings -> RP -> [2] DOMAIN
# Findings -> RP -> [3] USUBJID
# Findings -> RP -> [4] RPSEQ
# Findings -> RP -> [5] RPGRPID
# Findings -> RP -> [6] RPREFID
# Findings -> RP -> [7] RPSPID
# Findings -> RP -> [8] RPTESTCD
# Findings -> RP -> [9] RPTEST
# Findings -> RP -> [10] RPCAT
# Findings -> RP -> [11] RPSCAT
# Findings -> RP -> [12] RPORRES
# Findings -> RP -> [13] RPORRESU
# Findings -> RP -> [14] RPSTRESC
# Findings -> RP -> [15] RPSTRESN
# Findings -> RP -> [16] RPSTRESU
# Findings -> RP -> [17] RPSTAT
# Findings -> RP -> [18] RPREASND
# Findings -> RP -> [19] RPBLFL
# Findings -> RP -> [20] RPDRVFL
# Findings -> RP -> [21] VISITNUM
# Findings -> RP -> [22] VISIT
# Findings -> RP -> [23] VISITDY
# Findings -> RP -> [24] RPDTC
# Findings -> RP -> [25] RPDY
# Findings -> SC -> [1] STUDYID
# Findings -> SC -> [2] DOMAIN
# Findings -> SC -> [3] USUBJID
# Findings -> SC -> [4] SCSEQ
# Findings -> SC -> [5] SCGRPID
# Findings -> SC -> [6] SCSPID
# Findings -> SC -> [7] SCTESTCD
# Findings -> SC -> [8] SCTEST
# Findings -> SC -> [9] SCCAT
# Findings -> SC -> [10] SCSCAT
# Findings -> SC -> [11] SCORRES
# Findings -> SC -> [12] SCORRESU
# Findings -> SC -> [13] SCSTRESC
# Findings -> SC -> [14] SCSTRESN
# Findings -> SC -> [15] SCSTRESU
# Findings -> SC -> [16] SCSTAT
# Findings -> SC -> [17] SCREASND
# Findings -> SC -> [18] SCDTC
# Findings -> SC -> [19] SCDY
# Findings -> SS -> [1] STUDYID
# Findings -> SS -> [2] DOMAIN
# Findings -> SS -> [3] USUBJID
# Findings -> SS -> [4] SSSEQ
# Findings -> SS -> [5] SSGRPID
# Findings -> SS -> [6] SSSPID
# Findings -> SS -> [7] SSTESTCD
# Findings -> SS -> [8] SSTEST
# Findings -> SS -> [9] SSCAT
# Findings -> SS -> [10] SSSCAT
# Findings -> SS -> [11] SSORRES
# Findings -> SS -> [12] SSSTRESC
# Findings -> SS -> [13] SSSTAT
# Findings -> SS -> [14] SSREASND
# Findings -> SS -> [15] SSEVAL
# Findings -> SS -> [16] VISITNUM
# Findings -> SS -> [17] VISIT
# Findings -> SS -> [18] VISITDY
# Findings -> SS -> [19] SSDTC
# Findings -> SS -> [20] SSDY
# Findings -> TU -> [1] STUDYID
# Findings -> TU -> [2] DOMAIN
# Findings -> TU -> [3] USUBJID
# Findings -> TU -> [4] TUSEQ
# Findings -> TU -> [5] TUGRPID
# Findings -> TU -> [6] TUREFID
# Findings -> TU -> [7] TUSPID
# Findings -> TU -> [8] TULNKID
# Findings -> TU -> [9] TUTESTCD
# Findings -> TU -> [10] TUTEST
# Findings -> TU -> [11] TUORRES
# Findings -> TU -> [12] TUSTRESC
# Findings -> TU -> [13] TUNAM
# Findings -> TU -> [14] TULOC
# Findings -> TU -> [15] TULAT
# Findings -> TU -> [16] TUDIR
# Findings -> TU -> [17] TUPORTOT
# Findings -> TU -> [18] TUMETHOD
# Findings -> TU -> [19] TUEVAL
# Findings -> TU -> [20] TUEVALID
# Findings -> TU -> [21] TUACPTFL
# Findings -> TU -> [22] VISITNUM
# Findings -> TU -> [23] VISIT
# Findings -> TU -> [24] VISITDY
# Findings -> TU -> [25] EPOCH
# Findings -> TU -> [26] TUDTC
# Findings -> TU -> [27] TUDY
# Findings -> TR -> [1] STUDYID
# Findings -> TR -> [2] DOMAIN
# Findings -> TR -> [3] USUBJID
# Findings -> TR -> [4] TRSEQ
# Findings -> TR -> [5] TRGRPID
# Findings -> TR -> [6] TRREFID
# Findings -> TR -> [7] TRSPID
# Findings -> TR -> [8] TRLNKID
# Findings -> TR -> [9] TRLNKGRP
# Findings -> TR -> [10] TRTESTCD
# Findings -> TR -> [11] TRTEST
# Findings -> TR -> [12] TRORRES
# Findings -> TR -> [13] TRORRESU
# Findings -> TR -> [14] TRSTRESC
# Findings -> TR -> [15] TRSTRESN
# Findings -> TR -> [16] TRSTRESU
# Findings -> TR -> [17] TRSTAT
# Findings -> TR -> [18] TRREASND
# Findings -> TR -> [19] TRNAM
# Findings -> TR -> [20] TRMETHOD
# Findings -> TR -> [21] TREVAL
# Findings -> TR -> [22] TREVALID
# Findings -> TR -> [23] TRACPTFL
# Findings -> TR -> [24] VISITNUM
# Findings -> TR -> [25] VISIT
# Findings -> TR -> [26] VISITDY
# Findings -> TR -> [27] EPOCH
# Findings -> TR -> [28] TRDTC
# Findings -> TR -> [29] TRDY
# Findings -> RS -> [1] STUDYID
# Findings -> RS -> [2] DOMAIN
# Findings -> RS -> [3] USUBJID
# Findings -> RS -> [4] RSSEQ
# Findings -> RS -> [5] RSGRPID
# Findings -> RS -> [6] RSREFID
# Findings -> RS -> [7] RSSPID
# Findings -> RS -> [8] RSLNKID
# Findings -> RS -> [9] RSLNKGRP
# Findings -> RS -> [10] RSTESTCD
# Findings -> RS -> [11] RSTEST
# Findings -> RS -> [12] RSCAT
# Findings -> RS -> [13] RSORRES
# Findings -> RS -> [14] RSSTRESC
# Findings -> RS -> [15] RSSTAT
# Findings -> RS -> [16] RSREASND
# Findings -> RS -> [17] RSNAM
# Findings -> RS -> [18] RSEVAL
# Findings -> RS -> [19] RSEVALID
# Findings -> RS -> [20] RSACPTFL
# Findings -> RS -> [21] VISITNUM
# Findings -> RS -> [22] VISIT
# Findings -> RS -> [23] VISITDY
# Findings -> RS -> [24] EPOCH
# Findings -> RS -> [25] RSDTC
# Findings -> RS -> [26] RSDY
# Findings -> VS -> [1] STUDYID
# Findings -> VS -> [2] DOMAIN
# Findings -> VS -> [3] USUBJID
# Findings -> VS -> [4] VSSEQ
# Findings -> VS -> [5] VSGRPID
# Findings -> VS -> [6] VSSPID
# Findings -> VS -> [7] VSTESTCD
# Findings -> VS -> [8] VSTEST
# Findings -> VS -> [9] VSCAT
# Findings -> VS -> [10] VSSCAT
# Findings -> VS -> [11] VSPOS
# Findings -> VS -> [12] VSORRES
# Findings -> VS -> [13] VSORRESU
# Findings -> VS -> [14] VSSTRESC
# Findings -> VS -> [15] VSSTRESN
# Findings -> VS -> [16] VSSTRESU
# Findings -> VS -> [17] VSSTAT
# Findings -> VS -> [18] VSREASND
# Findings -> VS -> [19] VSLOC
# Findings -> VS -> [20] VSLAT
# Findings -> VS -> [21] VSBLFL
# Findings -> VS -> [22] VSDRVFL
# Findings -> VS -> [23] VISITNUM
# Findings -> VS -> [24] VISIT
# Findings -> VS -> [25] VISITDY
# Findings -> VS -> [26] VSDTC
# Findings -> VS -> [27] VSDY
# Findings -> VS -> [28] VSTPT
# Findings -> VS -> [29] VSTPTNUM
# Findings -> VS -> [30] VSELTM
# Findings -> VS -> [31] VSTPTREF
# Findings -> VS -> [32] VSRFTDTC
# Findings About -> FA -> [1] STUDYID
# Findings About -> FA -> [2] DOMAIN
# Findings About -> FA -> [3] USUBJID
# Findings About -> FA -> [4] FASEQ
# Findings About -> FA -> [5] FAGRPID
# Findings About -> FA -> [6] FASPID
# Findings About -> FA -> [7] FATESTCD
# Findings About -> FA -> [8] FATEST
# Findings About -> FA -> [9] FAOBJ
# Findings About -> FA -> [10] FACAT
# Findings About -> FA -> [11] FASCAT
# Findings About -> FA -> [12] FAORRES
# Findings About -> FA -> [13] FAORRESU
# Findings About -> FA -> [14] FASTRESC
# Findings About -> FA -> [15] FASTRESN
# Findings About -> FA -> [16] FASTRESU
# Findings About -> FA -> [17] FASTAT
# Findings About -> FA -> [18] FAREASND
# Findings About -> FA -> [19] FALOC
# Findings About -> FA -> [20] FALAT
# Findings About -> FA -> [21] FABLFL
# Findings About -> FA -> [22] FAEVAL
# Findings About -> FA -> [23] VISITNUM
# Findings About -> FA -> [24] VISIT
# Findings About -> FA -> [25] VISITDY
# Findings About -> FA -> [26] FADTC
# Findings About -> FA -> [27] FADY
# Findings About -> SR -> [1] STUDYID
# Findings About -> SR -> [2] DOMAIN
# Findings About -> SR -> [3] USUBJID
# Findings About -> SR -> [4] SRSEQ
# Findings About -> SR -> [5] SRGRPID
# Findings About -> SR -> [6] SRREFID
# Findings About -> SR -> [7] SRSPID
# Findings About -> SR -> [8] SRTESTCD
# Findings About -> SR -> [9] SRTEST
# Findings About -> SR -> [10] SROBJ
# Findings About -> SR -> [11] SRCAT
# Findings About -> SR -> [12] SRSCAT
# Findings About -> SR -> [13] SRORRES
# Findings About -> SR -> [14] SRORRESU
# Findings About -> SR -> [15] SRSTRESC
# Findings About -> SR -> [16] SRSTRESN
# Findings About -> SR -> [17] SRSTRESU
# Findings About -> SR -> [18] SRSTAT
# Findings About -> SR -> [19] SRREASND
# Findings About -> SR -> [20] SRNAM
# Findings About -> SR -> [21] SRSPEC
# Findings About -> SR -> [22] SRLOC
# Findings About -> SR -> [23] SRLAT
# Findings About -> SR -> [24] SRMETHOD
# Findings About -> SR -> [25] SREVAL
# Findings About -> SR -> [26] VISITNUM
# Findings About -> SR -> [27] VISIT
# Findings About -> SR -> [28] VISITDY
# Findings About -> SR -> [29] SRDTC
# Findings About -> SR -> [30] SRDY
# Findings About -> SR -> [31] SRTPT
# Findings About -> SR -> [32] SRTPTNUM
# Findings About -> SR -> [33] SRELTM
# Findings About -> SR -> [34] SRTPTREF
# Findings About -> SR -> [35] SRRFTDTC
# Trial Design -> TA -> [1] STUDYID
# Trial Design -> TA -> [2] DOMAIN
# Trial Design -> TA -> [3] ARMCD
# Trial Design -> TA -> [4] ARM
# Trial Design -> TA -> [5] TAETORD
# Trial Design -> TA -> [6] ETCD
# Trial Design -> TA -> [7] ELEMENT
# Trial Design -> TA -> [8] TABRANCH
# Trial Design -> TA -> [9] TATRANS
# Trial Design -> TA -> [10] EPOCH
# Trial Design -> TE -> [1] STUDYID
# Trial Design -> TE -> [2] DOMAIN
# Trial Design -> TE -> [3] ETCD
# Trial Design -> TE -> [4] ELEMENT
# Trial Design -> TE -> [5] TESTRL
# Trial Design -> TE -> [6] TEENRL
# Trial Design -> TE -> [7] TEDUR
# Trial Design -> TV -> [1] STUDYID
# Trial Design -> TV -> [2] DOMAIN
# Trial Design -> TV -> [3] VISITNUM
# Trial Design -> TV -> [4] VISIT
# Trial Design -> TV -> [5] VISITDY
# Trial Design -> TV -> [6] ARMCD
# Trial Design -> TV -> [7] ARM
# Trial Design -> TV -> [8] TVSTRL
# Trial Design -> TV -> [9] TVENRL
# Trial Design -> TD -> [1] STUDYID
# Trial Design -> TD -> [2] DOMAIN
# Trial Design -> TD -> [3] TDORDER
# Trial Design -> TD -> [4] TDANCVAR
# Trial Design -> TD -> [5] TDSTOFF
# Trial Design -> TD -> [6] TDTGTPAI
# Trial Design -> TD -> [7] TDMINPAI
# Trial Design -> TD -> [8] TDMAXPAI
# Trial Design -> TD -> [9] TDNUMRPT
# Trial Design -> TI -> [1] STUDYID
# Trial Design -> TI -> [2] DOMAIN
# Trial Design -> TI -> [3] IETESTCD
# Trial Design -> TI -> [4] IETEST
# Trial Design -> TI -> [5] IECAT
# Trial Design -> TI -> [6] IESCAT
# Trial Design -> TI -> [7] TIRL
# Trial Design -> TI -> [8] TIVERS
# Trial Design -> TS -> [1] STUDYID
# Trial Design -> TS -> [2] DOMAIN
# Trial Design -> TS -> [3] TSSEQ
# Trial Design -> TS -> [4] TSGRPID
# Trial Design -> TS -> [5] TSPARMCD
# Trial Design -> TS -> [6] TSPARM
# Trial Design -> TS -> [7] TSVAL
# Trial Design -> TS -> [8] TSVALNF
# Trial Design -> TS -> [9] TSVALCD
# Trial Design -> TS -> [10] TSVCDREF
# Trial Design -> TS -> [11] TSVCDVER
# Relationship -> RELREC -> [1] STUDYID
# Relationship -> RELREC -> [2] RDOMAIN
# Relationship -> RELREC -> [3] USUBJID
# Relationship -> RELREC -> [4] IDVAR
# Relationship -> RELREC -> [5] IDVARVAL
# Relationship -> RELREC -> [6] RELTYPE
# Relationship -> RELREC -> [7] RELID
# Relationship -> SUPPQUAL -> [1] STUDYID
# Relationship -> SUPPQUAL -> [2] RDOMAIN
# Relationship -> SUPPQUAL -> [3] USUBJID
# Relationship -> SUPPQUAL -> [4] IDVAR
# Relationship -> SUPPQUAL -> [5] IDVARVAL
# Relationship -> SUPPQUAL -> [6] QNAM
# Relationship -> SUPPQUAL -> [7] QLABEL
# Relationship -> SUPPQUAL -> [8] QVAL
# Relationship -> SUPPQUAL -> [9] QORIG
# Relationship -> SUPPQUAL -> [10] QEVAL

# %%
# can go directly to the datasets
datasets = client.get(f"{CDISC_API_URL}/mdr/sdtmig/3-2/datasets").json()

# %%
dm = None
# the href attribute is a link that you can reuse with the BASE URI
for dataset_link in datasets.get('_links').get('datasets'):
    if dataset_link.get('title') == 'Demographics':
        dm = client.get(f"{CDISC_API_URL}{dataset_link.get('href')}").json()

# %%
print(dm.get('name'))
print(dm.get('description'))
print(dm.get('_links'))

# pull the variables for the dataset
for dv in dm.get('datasetVariables'):
    print(f"{dm.get('name')} -> {dv.get('name')}")
# Out:
# DM
# A special-purpose domain that includes a set of essential standard variables that describe each subject in a clinical study. It is the parent domain for all other observations for human clinical subjects. (Source: CDISC Controlled Terminology, DOMAIN, C49572, 2018-06-29)
# {'modelDataset': {'href': '/mdr/sdtm/1-4/datasets/DM', 'title': 'Demographics', 'type': 'SDTM Dataset'}, 'parentClass': {'href': '/mdr/sdtmig/3-2/classes/SpecialPurpose', 'title': 'Special-Purpose Datasets', 'type': 'Class'}, 'parentProduct': {'href': '/mdr/sdtmig/3-2', 'title': 'Study Data Tabulation Model Implementation Guide: Human Clinical Trials Version 3.2 (Final)', 'type': 'Implementation Guide'}, 'priorVersion': {'href': '/mdr/sdtmig/3-1-3/datasets/DM', 'title': 'Demographics', 'type': 'SDTM Dataset'}, 'self': {'href': '/mdr/sdtmig/3-2/datasets/DM', 'title': 'Demographics', 'type': 'SDTM Dataset'}}
# DM -> STUDYID
# DM -> DOMAIN
# DM -> USUBJID
# DM -> SUBJID
# DM -> RFSTDTC
# DM -> RFENDTC
# DM -> RFXSTDTC
# DM -> RFXENDTC
# DM -> RFICDTC
# DM -> RFPENDTC
# DM -> DTHDTC
# DM -> DTHFL
# DM -> SITEID
# DM -> INVID
# DM -> INVNAM
# DM -> BRTHDTC
# DM -> AGE
# DM -> AGEU
# DM -> SEX
# DM -> RACE
# DM -> ETHNIC
# DM -> ARMCD
# DM -> ARM
# DM -> ACTARMCD
# DM -> ACTARM
# DM -> COUNTRY
# DM -> DMDTC
# DM -> DMDY

# %%
import pprint
# The dataset variables also have accessible attributes

# pull the variables for the dataset
for dv in dm.get('datasetVariables'):
    if dv.get('name') == 'SEX':
        print(pprint.pprint(dv))
# Out:
# {'_links': {'codelist': [{'href': '/mdr/root/ct/sdtmct/codelists/C66731',
#                           'title': 'Version-agnostic anchor resource for '
#                                    'codelist C66731',
#                           'type': 'Root Value Domain'}],
#             'modelDatasetVariable': {'href': '/mdr/sdtm/1-4/datasets/DM/variables/SEX',
#                                      'title': 'Sex',
#                                      'type': 'SDTM Dataset Variable'},
#             'parentDataset': {'href': '/mdr/sdtmig/3-2/datasets/DM',
#                               'title': 'Demographics',
#                               'type': 'SDTM Dataset'},
#             'parentProduct': {'href': '/mdr/sdtmig/3-2',
#                               'title': 'Study Data Tabulation Model '
#                                        'Implementation Guide: Human Clinical '
#                                        'Trials Version 3.2 (Final)',
#                               'type': 'Implementation Guide'},
#             'priorVersion': {'href': '/mdr/sdtmig/3-1-3/datasets/DM/variables/SEX',
#                              'title': 'Sex',
#                              'type': 'SDTM Dataset Variable'},
#             'rootItem': {'href': '/mdr/root/sdtmig/datasets/DM/variables/SEX',
#                          'title': 'Version-agnostic anchor resource for SDTMIG '
#                                   'variable DM.SEX',
#                          'type': 'Root Data Element'},
#             'self': {'href': '/mdr/sdtmig/3-2/datasets/DM/variables/SEX',
#                      'title': 'Sex',
#                      'type': 'SDTM Dataset Variable'}},
#  'core': 'Req',
#  'description': 'Sex of the subject.',
#  'label': 'Sex',
#  'name': 'SEX',
#  'ordinal': '19',
#  'role': 'Record Qualifier',
#  'simpleDatatype': 'Char'}
# None

# %% [markdown]
# # API Specifications
#
# The APIs themselves are sensible in terms of how they are laid out; we go from context (eg SDTM IG) to version (eg 3-3) to dataset (eg DM) to variable (eg SEX).  The API is documented using a standard called OpenAPI (previously known as Swagger) - this is a format for publishing information about an API; information includes:
# * Routes (where to get the data)
# * Methods (how to access the data, usually using HTTP Verbs)
# * Formats (what parameters are required)
# * Structures (how the data looks)
# * Responses (what outcomes can you expect)
#
# The use of standard representations makes the developer view ([here](https://www.cdisc.org/cdisc-library/api-documentation))
#
# Using a standard OpenAPI based webservice makes it easier for developers to access and understand what the API exposes.  You can use tools to automatically generate clients so code like the following is possible (this was built using [openapi-python-client](https://github.com/openapi-generators/openapi-python-client)):
#
# ```python
# # create a module and then use the module
# from cdisc_library_api_client.api.sdtm.ig.sdtmig_get_dataset import sync_detailed
#
# # URL construction and authentication are handled transparently
# client = AuthenticatedClient(base_url="https://library.cdisc.org/api", token=token)
#
# token = os.getenv("CDISC_LIBRARY_TOKEN")
#
# # Specifications
# version = "3-3"
# domain = "DM"
#
# # make the call
# mm = await sync_detailed(client=client, version=version, dataset=domain)
# dataset = mm.parsed
#
# # dataset is an instance of an SDTMigDataset
# print("Dataset: {dataset.name} ({dataset.label})")
# ```
